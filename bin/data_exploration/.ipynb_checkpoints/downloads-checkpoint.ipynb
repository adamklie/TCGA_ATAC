# %%
import os
import pandas as pd
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
os.chdir("/cellar/users/aklie/data/datasets/TCGA_ATAC")

# %%
pd.read_excel("metadata/2024_02_15/148b8d1e-a132-48f6-8e40-9ca96aa2f9b2", sheet_name=0)
# Out:
#                                 Data S1 - Page 1 of 3  \
# 0   This page of the table shows the pass/fail rat...
# 1                                Related to Figure 1A
# 2                                                 NaN
# 3                                     Row Explanation
# 4   Each row represents a different cancer type pr...
# 5                                                 NaN
# 6                                 Column Explanations
# 7   Abbreviation - The TCGA standard abbreviation ...
# 8   Cancer Type - The long form name of each cance...
# 9   Number of Donors Passed QC - The number of don...
# 10  Number of Donors Failed QC - The number of don...
# 11  Number of Tissue Samples Passed QC - The numbe...
# 12  Number of Tissue Samples Failed QC - The numbe...
# 13  Number of Passed QC Samples with 1 TechRep - T...
# 14  Number of Passed QC Samples with 2 TechReps - ...
# 15  Total Libraries Generated - The total number o...
# ...
